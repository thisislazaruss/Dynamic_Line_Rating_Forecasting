# %%
import pandas as pd
import numpy as np
df=pd.read_excel('data.xlsx')
df
# Out:
#                       time  ghi  air_temperature  wind_speed
# 0      2018-07-01 00:01:00  0.0             26.7         2.5
# 1      2018-07-01 00:02:00  0.0             26.7         2.3
# 2      2018-07-01 00:03:00  0.0             26.7         2.4
# 3      2018-07-01 00:04:00  0.0             26.7         2.5
# 4      2018-07-01 00:05:00  0.0             26.8         2.1
# ...                    ...  ...              ...         ...
# 614877 2019-08-31 23:56:00  0.0             26.2         0.2
# 614878 2019-08-31 23:57:00  0.0             26.2         0.1
# 614879 2019-08-31 23:58:00  0.0             26.2         0.0
# 614880 2019-08-31 23:59:00  0.0             26.2         0.0
# 614881 2019-09-01 00:00:00  0.0             26.2         0.0
#
# [614882 rows x 4 columns]

# %%
from sklearn.datasets import load_diabetes 
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import pandas as pd

# %%
pip install seaborn
# Out:
# ...
#
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.datasets import load_diabetes 
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import pandas as pd

# %%
df
# Out:
#                       time  ghi  air_temperature  wind_speed
# 0      2018-07-01 00:01:00  0.0             26.7         2.5
# 1      2018-07-01 00:02:00  0.0             26.7         2.3
# 2      2018-07-01 00:03:00  0.0             26.7         2.4
# 3      2018-07-01 00:04:00  0.0             26.7         2.5
# 4      2018-07-01 00:05:00  0.0             26.8         2.1
# ...                    ...  ...              ...         ...
# 614877 2019-08-31 23:56:00  0.0             26.2         0.2
# 614878 2019-08-31 23:57:00  0.0             26.2         0.1
# 614879 2019-08-31 23:58:00  0.0             26.2         0.0
# 614880 2019-08-31 23:59:00  0.0             26.2         0.0
# 614881 2019-09-01 00:00:00  0.0             26.2         0.0
#
# [614882 rows x 4 columns]

# %%
ghi = df.ghi
atemp = df.air_temperature
wind = df.wind_speed

# %%
[ghi.shape, atemp.shape, wind.shape]
# Out:
# [(614882,), (614882,), (614882,)]

# %%
fig=plt.figure(figsize=(10,5), dpi= 200, facecolor='w', edgecolor='k')
plt.subplot(1,3,1), plt.hist(ghi)
plt.subplot(1,3,2), plt.hist(atemp)
plt.subplot(1,3,3), plt.hist(wind)
# Out:
# (<AxesSubplot:>,
#  (array([3.24485e+05, 1.76741e+05, 5.04140e+04, 1.49590e+04, 3.04500e+03,
#          4.74000e+02, 9.70000e+01, 1.80000e+01, 6.00000e+00, 1.00000e+00]),
#   array([ 0. ,  1.5,  3. ,  4.5,  6. ,  7.5,  9. , 10.5, 12. , 13.5, 15. ]),
#   <BarContainer object of 10 artists>))

# %%
# intialize disfit
from distfit import distfit

# %%
# solar irradiance best fit distribution
dist=distfit()
ghi = pd.Series.to_numpy(ghi)
ghi = ghi[~np.isnan(ghi)]
dist.fit_transform(ghi)
# Out:
# [distfit] >fit..
# [distfit] >transform..
# [distfit] >[norm      ] [0.00 sec] [RSS: 0.000275542] [loc=195.064 scale=283.290]
# [distfit] >[expon     ] [0.00 sec] [RSS: 0.00019577] [loc=0.000 scale=195.064]
# [distfit] >[pareto    ] [27.2 sec] [RSS: 0.00012587] [loc=-0.849 scale=0.849]
# [distfit] >[dweibull  ] [12.3 sec] [RSS: 0.000264926] [loc=123.552 scale=227.970]
# [distfit] >[t         ] [20.6 sec] [RSS: 0.000309505] [loc=0.000 scale=0.000]
# [distfit] >[genextreme] [76.9 sec] [RSS: 0.000314924] [loc=0.000 scale=0.000]
# [distfit] >[gamma     ] [18.5 sec] [RSS: 7.88644e-05] [loc=-0.000 scale=192.976]
# [distfit] >[lognorm   ] [45.3 sec] [RSS: 0.000233175] [loc=-0.000 scale=238.433]
# [distfit] >[beta      ] [37.9 sec] [RSS: 0.000180104] [loc=-0.000 scale=1946.456]
# [distfit] >[uniform   ] [0.00 sec] [RSS: 0.000294431] [loc=0.000 scale=1562.000]
# [distfit] >[loggamma  ] [19.1 sec] [RSS: 0.000276097] [loc=-87603.080 scale=11821.938]
# ...

# %%
print(dist.summary)
# Out:
#          distr     score  LLE           loc         scale  \
# 0        gamma  0.000079  NaN          -0.0    192.975824
# 1       pareto  0.000126  NaN     -0.848913      0.848913
# 2         beta   0.00018  NaN          -0.0   1946.456284
# 3        expon  0.000196  NaN           0.0    195.063565
# 4      lognorm  0.000233  NaN          -0.0    238.432896
# 5     dweibull  0.000265  NaN    123.551608    227.969638
# 6         norm  0.000276  NaN    195.063565    283.290027
# 7     loggamma  0.000276  NaN -87603.079975  11821.937875
# 8      uniform  0.000294  NaN           0.0        1562.0
# 9            t   0.00031  NaN           0.0           0.0
# 10  genextreme  0.000315  NaN           0.0           0.0
#
#                                          arg
# 0                      (0.3707162192614287,)
# 1                      (0.5527898960950863,)
# 2   (0.3963387018689104, 1.3029024826374647)
# 3                                         ()
# ...

# %%
dist.plot()
# Out:
# [distfit] >plot..
# (<Figure size 720x576 with 1 Axes>,
#  <AxesSubplot:title={'center':'\ngamma\nRSS(a=0.370716, loc=-1.26988e-25, scale=192.976)'}, xlabel='Values', ylabel='Frequency'>)

# %%
# temperature best fit distribution
atemp = df.air_temperature
dist=distfit()
atemp = pd.Series.to_numpy(atemp)
atemp = atemp[~np.isnan(atemp)]
dist.fit_transform(atemp)
# Out:
# [distfit] >fit..
# [distfit] >transform..
# [distfit] >[norm      ] [0.00 sec] [RSS: 0.0081244] [loc=24.873 scale=4.923]
# [distfit] >[expon     ] [0.00 sec] [RSS: 0.0716817] [loc=9.400 scale=15.473]
# [distfit] >[pareto    ] [21.7 sec] [RSS: 0.1069] [loc=-0.050 scale=9.450]
# [distfit] >[dweibull  ] [11.0 sec] [RSS: 0.0131254] [loc=24.653 scale=4.416]
# [distfit] >[t         ] [23.7 sec] [RSS: 0.00812458] [loc=24.873 scale=4.923]
# [distfit] >[genextreme] [94.7 sec] [RSS: 0.00628475] [loc=23.365 scale=4.986]
# [distfit] >[gamma     ] [19.2 sec] [RSS: 0.00960196] [loc=-51.863 scale=0.331]
# [distfit] >[lognorm   ] [55.2 sec] [RSS: 0.00959569] [loc=-53.253 scale=78.093]
# [distfit] >[beta      ] [43.1 sec] [RSS: 0.00332567] [loc=-48.413 scale=87.332]
# [distfit] >[uniform   ] [0.00 sec] [RSS: 0.0437228] [loc=9.400 scale=28.800]
# [distfit] >[loggamma  ] [5.26 sec] [RSS: 0.00298372] [loc=21.930 scale=6.352]
# [distfit] >Compute confidence interval [parametric]
# ...

# %%
print(dist.summary)
# Out:
#          distr     score  LLE        loc      scale  \
# 0     loggamma  0.002984  NaN  21.929974   6.351574
# 1         beta  0.003326  NaN -48.413277  87.332378
# 2   genextreme  0.006285  NaN  23.365363   4.986398
# 3         norm  0.008124  NaN   24.87308   4.922872
# 4            t  0.008125  NaN  24.872971   4.923017
# 5      lognorm  0.009596  NaN -53.253332  78.093423
# 6        gamma  0.009602  NaN -51.863451   0.331134
# 7     dweibull  0.013125  NaN  24.652775   4.416397
# 8      uniform  0.043723  NaN        9.4       28.8
# 9        expon  0.071682  NaN        9.4   15.47308
# 10      pareto    0.1069  NaN  -0.050463   9.450463
#
#                                        arg
# 0                    (2.0641820264691724,)
# 1   (35.26886856888218, 6.764983361829652)
# 2                    (0.3349462375688458,)
# 3                                       ()
# 4                     (5677887.738155432,)
# 5                   (0.06442006876115011,)
# ...

# %%
dist.plot()
# Out:
# [distfit] >plot..
# (<Figure size 720x576 with 1 Axes>,
#  <AxesSubplot:title={'center':'\nloggamma\nRSS(c=2.06418, loc=21.93, scale=6.35157)'}, xlabel='Values', ylabel='Frequency'>)

# %%
wind = wind[~np.isnan(wind)]

# %%
dist.fit_transform(wind)
# Out:
# [distfit] >Cleaning previous fitted model results..
# [distfit] >fit..
# [distfit] >transform..
# [distfit] >[norm      ] [0.01 sec] [RSS: 0.598578] [loc=1.392 scale=1.347]
# [distfit] >[expon     ] [0.00 sec] [RSS: 0.267699] [loc=0.000 scale=1.392]
# [distfit] >[pareto    ] [23.5 sec] [RSS: 0.215092] [loc=-0.826 scale=0.826]
# [distfit] >[dweibull  ] [9.85 sec] [RSS: 0.549766] [loc=1.156 scale=1.145]
# [distfit] >[t         ] [17.8 sec] [RSS: 0.592323] [loc=1.267 scale=1.164]
# [distfit] >[genextreme] [31.9 sec] [RSS: 0.419053] [loc=0.604 scale=0.791]
# [distfit] >[gamma     ] [22.0 sec] [RSS: 0.363953] [loc=-0.000 scale=1.021]
# [distfit] >[lognorm   ] [50.0 sec] [RSS: 0.587568] [loc=-0.000 scale=0.124]
# [distfit] >[beta      ] [44.3 sec] [RSS: 0.273041] [loc=-0.000 scale=44.230]
# [distfit] >[uniform   ] [0.00 sec] [RSS: 1.17203] [loc=0.000 scale=15.000]
# [distfit] >[loggamma  ] [19.8 sec] [RSS: 0.600772] [loc=-368.996 scale=51.072]
# ...

# %%
print(dist.summary)
# Out:
#          distr     score  LLE         loc      scale  \
# 0       pareto  0.215092  NaN   -0.826316   0.826316
# 1        expon  0.267699  NaN         0.0   1.392263
# 2         beta  0.273041  NaN        -0.0  44.230059
# 3        gamma  0.363953  NaN        -0.0   1.020993
# 4   genextreme  0.419053  NaN    0.604081    0.79135
# 5     dweibull  0.549766  NaN    1.156348   1.145195
# 6      lognorm  0.587568  NaN        -0.0   0.124448
# 7            t  0.592323  NaN    1.267228    1.16449
# 8         norm  0.598578  NaN    1.392263   1.346719
# 9     loggamma  0.600772  NaN -368.996494  51.071995
# 10     uniform  1.172028  NaN         0.0       15.0
#
#                                           arg
# 0                       (1.1005974880908782,)
# 1                                          ()
# 2   (0.19341269009287937, 22.661512476448383)
# 3                       (0.6843073502031809,)
# 4                      (-0.3942389662379894,)
# ...

# %%
dist.plot()
# Out:
# [distfit] >plot..
# (<Figure size 720x576 with 1 Axes>,
#  <AxesSubplot:title={'center':'\npareto\nRSS(b=1.1006, loc=-0.826316, scale=0.826316)'}, xlabel='Values', ylabel='Frequency'>)
